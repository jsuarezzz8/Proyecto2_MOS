# %% [markdown]
# <a href="https://colab.research.google.com/github/jsuarezzz8/Proyecto2_MOS/blob/main/Proyecto2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import sys
import os


if 'google.colab' in sys.modules:

    # !pip install idaes-pse --pre
    # !idaes get-extensions --to ./bin
    os.environ['PATH'] += ':bin'


    # !apt-get install -y -qq glpk-utils
    # !apt-get install -y coinor-libhighs-dev
    # !pip install gurobipy
    # !pip install amplpy pyomo -q
    # !python -m amplpy.modules install coin highs scip gcg -q

    # !pip install pyomo
    # !pip install folium
    # !pip install polyline
    # !pip install branca
    # !apt-get install -y coinor-cbc
# Crear archivo de licencia
    os.makedirs("/root/gurobi", exist_ok=True)
    with open("/root/gurobi/gurobi.lic", "w") as f:
        f.write("""LICENSEID=2662152
TYPE=ACADEMIC
VERSION=12
HOSTNAME=DESKTOP-M317T6F
HOSTID=40c938df
USERNAME=usuario
EXPIRATION=2026-05-07
""")
os.environ['GRB_LICENSE_FILE'] = "/root/gurobi/gurobi.lic"
os.environ['PATH'] += ":/opt/gurobi120/gurobi1201/linux64/bin"

# %%
import csv

def leer_datos_centro(archivo_centros):
    centros = {}

    # Leer centros
    with open(archivo_centros, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            centros["CD"+row['DepotID']] = {
                'lat': float(row['Latitude']),
                'lon': float(row['Longitude']),

            }

    return centros

def leer_datos_clientes( archivo_clientes):
    clientes = {}

    # Leer clientes
    with open(archivo_clientes, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            clientes["C"+row['ClientID']] = {
                'lat': float(row['Latitude']),
                'lon': float(row['Longitude']),
                'demanda': float(row['Demand'])
            }

    return clientes

def leer_datos_vehiculos(archivo_vehiculos):
    vehiculos = {}


    # Leer vehículos
    with open(archivo_vehiculos, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            vehiculos["V"+row['VehicleID']] = {
                'capacidad': float(row['Capacity']),
                'rango': float(row['Range'])
            }

    return  vehiculos

def leer_datos_centro_caso1(archivo_centros):
    centros = {}

    with open(archivo_centros, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        tiene_capacidad = 'Capacity' in reader.fieldnames  # Verifica si la columna existe

        for row in reader:
            capacidad = float(row['Capacity']) if tiene_capacidad else float('inf')
            centros["CD"+row['DepotID']] = {
                'lat': float(row['Latitude']),
                'lon': float(row['Longitude']),
                'capacidad': capacidad
            }

    return centros

# %%
# Puedes cambiar estos datos fácilmente
centros = leer_datos_centro_caso1('depots.csv')
clientes = leer_datos_clientes('clients.csv')
vehiculos = leer_datos_vehiculos('vehicles.csv')


print(centros)
print(clientes)
print(vehiculos)
# Out:
# {'CD1': {'lat': 4.743359, 'lon': -74.153536, 'capacidad': inf}}
# {'C1': {'lat': 4.59795431125545, 'lon': -74.09893796560621, 'demanda': 13.0}, 'C2': {'lat': 4.687820646838871, 'lon': -74.07557103763986, 'demanda': 15.0}, 'C3': {'lat': 4.70949446000624, 'lon': -74.10708524062704, 'demanda': 12.0}, 'C4': {'lat': 4.605029068682624, 'lon': -74.09727965657427, 'demanda': 15.0}, 'C5': {'lat': 4.648463876533332, 'lon': -74.16464148202755, 'demanda': 20.0}, 'C6': {'lat': 4.662137416953968, 'lon': -74.12083799988112, 'demanda': 17.0}, 'C7': {'lat': 4.697499030379109, 'lon': -74.02213076607309, 'demanda': 17.0}, 'C8': {'lat': 4.649416884236942, 'lon': -74.17207549744595, 'demanda': 20.0}, 'C9': {'lat': 4.606310650273935, 'lon': -74.15615257246444, 'demanda': 20.0}, 'C10': {'lat': 4.557379705282216, 'lon': -74.09041145358674, 'demanda': 15.0}, 'C11': {'lat': 4.591594072172954, 'lon': -74.17802255204528, 'demanda': 17.0}, 'C12': {'lat': 4.7564172406324055, 'lon': -74.1015410917749, 'demanda': 12.0}, 'C13': {'lat': 4.646217006050524, 'lon': -74.09690889182339, 'demanda': 21.0}, 'C14': {'lat': 4.725912125314368, 'lon': -74.1219200708342, 'demanda': 15.0}, 'C15': {'lat': 4.604168478560718, 'lon': -74.0942948461378, 'demanda': 17.0}, 'C16': {'lat': 4.557320898243896, 'lon': -74.11138839002187, 'demanda': 10.0}, 'C17': {'lat': 4.615869066082658, 'lon': -74.12463941285208, 'demanda': 25.0}, 'C18': {'lat': 4.656402930181292, 'lon': -74.12456164551857, 'demanda': 12.0}, 'C19': {'lat': 4.706188309535041, 'lon': -74.04990580408855, 'demanda': 11.0}, 'C20': {'lat': 4.746624762561149, 'lon': -74.121866801394, 'demanda': 15.0}, 'C21': {'lat': 4.746517184687941, 'lon': -74.02454895778163, 'demanda': 14.0}, 'C22': {'lat': 4.625425626584072, 'lon': -74.08683592702927, 'demanda': 18.0}, 'C23': {'lat': 4.731406773645735, 'lon': -74.11652648751144, 'demanda': 15.0}, 'C24': {'lat': 4.577489966973782, 'lon': -74.12629327283491, 'demanda': 11.0}}
# {'V1': {'capacidad': 130.0, 'rango': 170.0}, 'V2': {'capacidad': 140.0, 'rango': 200.0}, 'V3': {'capacidad': 120.0, 'rango': 180.0}, 'V4': {'capacidad': 100.0, 'rango': 90.0}, 'V5': {'capacidad': 70.0, 'rango': 100.0}, 'V6': {'capacidad': 55.0, 'rango': 170.0}, 'V7': {'capacidad': 110.0, 'rango': 150.0}, 'V8': {'capacidad': 114.0, 'rango': 140.0}}

# %%
import pyomo.environ as pyo
import time
from math import sqrt

def get_euclidean_distance(lat1, lon1, lat2, lon2):
    return sqrt((lat1 - lat2)**2 + (lon1 - lon2)**2) * 111

def modelo(centros, clientes, vehiculos):
    tiempo_inicio = time.time()
    nodos = list(centros.keys()) + list(clientes.keys())
    coordenadas = {**centros, **clientes}

    distancias = {
        (i, j): get_euclidean_distance(coordenadas[i]['lat'], coordenadas[i]['lon'],
                                       coordenadas[j]['lat'], coordenadas[j]['lon'])
        for i in nodos for j in nodos if i != j
    }

    P_f, F_t, C_m, alpha = 15000, 5000, 700, 0.025
    costo_km = F_t + alpha * P_f + C_m

    model = pyo.ConcreteModel()

    model.N = pyo.Set(initialize=nodos)
    model.C = pyo.Set(initialize=clientes.keys())
    model.D = pyo.Set(initialize=centros.keys())
    model.V = pyo.Set(initialize=vehiculos.keys())

    model.Q = pyo.Param(model.V, initialize=lambda m, v: vehiculos[v]['capacidad'])
    model.R = pyo.Param(model.V, initialize=lambda m, v: vehiculos[v]['rango'])
    model.q = pyo.Param(model.C, initialize=lambda m, i: clientes[i]['demanda'])

    model.Arcos = pyo.Set(initialize=[(i, j, v) for i in nodos for j in nodos if i != j for v in vehiculos])

    model.x = pyo.Var(model.Arcos, domain=pyo.Binary)
    model.y = pyo.Var(model.D, model.V, domain=pyo.Binary)
    model.u = pyo.Var(model.C, model.V, domain=pyo.NonNegativeReals, bounds=(1, len(clientes)))

    def objetivo(model):
        return sum(costo_km * distancias[i, j] * model.x[i, j, v] for (i, j, v) in model.Arcos)
    model.obj = pyo.Objective(rule=objetivo, sense=pyo.minimize)

    model.asignacion = pyo.Constraint(model.V, rule=lambda m, v: sum(m.y[k, v] for k in m.D) == 1)

    def visita_una_vez(m, j):
        return sum(m.x[i, j, v] for i in m.N for v in m.V if (i, j, v) in m.Arcos) == 1
    model.visita = pyo.Constraint(model.C, rule=visita_una_vez)

    def inicio(m, k, v):
        return sum(m.x[k, j, v] for j in m.N if (k, j, v) in m.Arcos) == m.y[k, v]
    model.inicio = pyo.Constraint(model.D, model.V, rule=inicio)

    def fin(m, k, v):
        return sum(m.x[j, k, v] for j in m.N if (j, k, v) in m.Arcos) == m.y[k, v]
    model.fin = pyo.Constraint(model.D, model.V, rule=fin)

    def flujo(m, j, v):
        return sum(m.x[i, j, v] for i in m.N if (i, j, v) in m.Arcos) == \
               sum(m.x[j, i, v] for i in m.N if (j, i, v) in m.Arcos)
    model.flujo = pyo.Constraint(model.C, model.V, rule=flujo)

    def capacidad(m, v):
        return sum(m.q[i] * sum(m.x[j, i, v] for j in m.N if (j, i, v) in m.Arcos) for i in m.C) <= m.Q[v]
    model.capacidad = pyo.Constraint(model.V, rule=capacidad)

    def autonomia(m, v):
        return sum(distancias[i, j] * m.x[i, j, v] for (i, j, vv) in m.Arcos if vv == v) <= m.R[v]
    model.autonomia = pyo.Constraint(model.V, rule=autonomia)

    def mtz(m, i, j, v):
        if i != j and i in m.C and j in m.C and (i, j, v) in m.Arcos:
            return m.u[i, v] - m.u[j, v] + len(m.C) * m.x[i, j, v] <= len(m.C) - 1
        return pyo.Constraint.Skip
    model.mtz = pyo.Constraint(model.C, model.C, model.V, rule=mtz)


    solver = pyo.SolverFactory('cbc')
    solver.options['seconds'] = 600

    results = solver.solve(model, tee=True)

    print(f"\n⏱ Tiempo total: {time.time() - tiempo_inicio:.2f} segundos")
    print(f"📉 Mejor valor encontrado: {pyo.value(model.obj):,.2f}")



    return model

# %%
import folium
import random
from folium import plugins

def mostrar_mapa_solucion(model, centros, clientes, vehiculos):
    # Crear mapa centrado en el primer centro
    centro_inicio = next(iter(centros.values()))
    mapa = folium.Map(location=[centro_inicio['lat'], centro_inicio['lon']], zoom_start=13)

    # Colores únicos para cada vehículo
    colores = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightblue', 'darkgreen']
    color_vehiculo = {v: colores[i % len(colores)] for i, v in enumerate(model.V)}

    # Agregar centros
    for k in centros:
        coord = centros[k]
        folium.Marker([coord['lat'], coord['lon']], popup=f"CD: {k}", icon=folium.Icon(color='black', icon='home')).add_to(mapa)

    # Agregar clientes
    for c in clientes:
        coord = clientes[c]
        folium.Marker([coord['lat'], coord['lon']], popup=f"Cliente: {c}\nDemanda: {clientes[c]['demanda']}", icon=folium.Icon(color='gray', icon='user')).add_to(mapa)

    # Dibujar rutas
    for (i, j, v) in model.Arcos:
        if pyo.value(model.x[i, j, v]) == 1:
            coord_i = centros[i] if i in centros else clientes[i]
            coord_j = centros[j] if j in centros else clientes[j]
            folium.PolyLine(
                locations=[(coord_i['lat'], coord_i['lon']), (coord_j['lat'], coord_j['lon'])],
                color=color_vehiculo[v],
                weight=4,
                tooltip=f"{v}: {i} → {j}"
            ).add_to(mapa)

    # Leyenda de colores por vehículo
    legend_html = """
    <div style='position: fixed; bottom: 20px; left: 20px; z-index:9999; background-color:white;
                padding: 10px; border:2px solid grey; border-radius:6px'>
      <h4 style='margin-top: 0'>Vehículos</h4>
    """
    for v in model.V:
        legend_html += f"<i style='background:{color_vehiculo[v]};width:10px;height:10px;display:inline-block;'></i> {v}<br>"
    legend_html += "</div>"
    mapa.get_root().html.add_child(folium.Element(legend_html))

    return mapa

# %%
# Puedes cambiar estos datos fácilmente
centros = leer_datos_centro_caso1('depots.csv')
clientes = leer_datos_clientes('clients.csv')
vehiculos = leer_datos_vehiculos('vehicles.csv')


print(centros)
print(clientes)
print(vehiculos)

model = modelo(centros,clientes,vehiculos)
mapa = mostrar_mapa_solucion(model, centros, clientes, vehiculos)
mapa.save("mapa_rutas.html")
mapa
# Out:
# {'CD1': {'lat': 4.743359, 'lon': -74.153536, 'capacidad': inf}}
# {'C1': {'lat': 4.59795431125545, 'lon': -74.09893796560621, 'demanda': 13.0}, 'C2': {'lat': 4.687820646838871, 'lon': -74.07557103763986, 'demanda': 15.0}, 'C3': {'lat': 4.70949446000624, 'lon': -74.10708524062704, 'demanda': 12.0}, 'C4': {'lat': 4.605029068682624, 'lon': -74.09727965657427, 'demanda': 15.0}, 'C5': {'lat': 4.648463876533332, 'lon': -74.16464148202755, 'demanda': 20.0}, 'C6': {'lat': 4.662137416953968, 'lon': -74.12083799988112, 'demanda': 17.0}, 'C7': {'lat': 4.697499030379109, 'lon': -74.02213076607309, 'demanda': 17.0}, 'C8': {'lat': 4.649416884236942, 'lon': -74.17207549744595, 'demanda': 20.0}, 'C9': {'lat': 4.606310650273935, 'lon': -74.15615257246444, 'demanda': 20.0}, 'C10': {'lat': 4.557379705282216, 'lon': -74.09041145358674, 'demanda': 15.0}, 'C11': {'lat': 4.591594072172954, 'lon': -74.17802255204528, 'demanda': 17.0}, 'C12': {'lat': 4.7564172406324055, 'lon': -74.1015410917749, 'demanda': 12.0}, 'C13': {'lat': 4.646217006050524, 'lon': -74.09690889182339, 'demanda': 21.0}, 'C14': {'lat': 4.725912125314368, 'lon': -74.1219200708342, 'demanda': 15.0}, 'C15': {'lat': 4.604168478560718, 'lon': -74.0942948461378, 'demanda': 17.0}, 'C16': {'lat': 4.557320898243896, 'lon': -74.11138839002187, 'demanda': 10.0}, 'C17': {'lat': 4.615869066082658, 'lon': -74.12463941285208, 'demanda': 25.0}, 'C18': {'lat': 4.656402930181292, 'lon': -74.12456164551857, 'demanda': 12.0}, 'C19': {'lat': 4.706188309535041, 'lon': -74.04990580408855, 'demanda': 11.0}, 'C20': {'lat': 4.746624762561149, 'lon': -74.121866801394, 'demanda': 15.0}, 'C21': {'lat': 4.746517184687941, 'lon': -74.02454895778163, 'demanda': 14.0}, 'C22': {'lat': 4.625425626584072, 'lon': -74.08683592702927, 'demanda': 18.0}, 'C23': {'lat': 4.731406773645735, 'lon': -74.11652648751144, 'demanda': 15.0}, 'C24': {'lat': 4.577489966973782, 'lon': -74.12629327283491, 'demanda': 11.0}}
# {'V1': {'capacidad': 130.0, 'rango': 170.0}, 'V2': {'capacidad': 140.0, 'rango': 200.0}, 'V3': {'capacidad': 120.0, 'rango': 180.0}, 'V4': {'capacidad': 100.0, 'rango': 90.0}, 'V5': {'capacidad': 70.0, 'rango': 100.0}, 'V6': {'capacidad': 55.0, 'rango': 170.0}, 'V7': {'capacidad': 110.0, 'rango': 150.0}, 'V8': {'capacidad': 114.0, 'rango': 140.0}}
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - /usr/bin/cbc -seconds 600 -printingOptions all -import /tmp/tmpav_2o237.pyomo.lp -stat=1 -solve -solu /tmp/tmpav_2o237.pyomo.soln (default strategy 1)
# seconds was changed from 1e+100 to 600
# Option for printingOptions changed from normal to all
# Presolve 4664 (-8) rows, 4992 (-8) columns and 36864 (-24) elements
# Statistics for presolved model
# Original problem has 4808 integers (4808 of which binary)
# Presolved problem has 4800 integers (4800 of which binary)
# ==== 192 zero objective 301 different
# ==== absolute objective values 301 different
# ==== for integers 0 zero objective 300 different
# ==== for integers absolute objective values 300 different
# ===== end objective counts
#
#
# Problem has 4664 rows, 4992 columns (4800 with objective) and 36864 elements
# Column breakdown:
# 0 of type 0.0->inf, 0 of type 0.0->up, 0 of type lo->inf,
# 192 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 4800 of type 0.0->1.0
# Row breakdown:
# 192 of type E 0.0, 40 of type E 1.0, 0 of type E -1.0,
# 0 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 0 of type L 0.0, 0 of type L 1.0,
# 4432 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is 918692 - 0.04 seconds
# Cgl0004I processed model has 4664 rows, 4992 columns (4800 integer (4800 of which binary)) and 36864 elements
# Cbc0038I Initial state - 35 integers unsatisfied sum - 4.08333
# Cbc0038I Pass   1: (0.15 seconds) suminf.    3.00000 (45) obj. 957534 iterations 302
# Cbc0038I Pass   2: (0.15 seconds) suminf.    3.00000 (48) obj. 1.018e+06 iterations 10
# Cbc0038I Pass   3: (0.20 seconds) suminf.    2.50000 (28) obj. 1.22984e+06 iterations 656
# Cbc0038I Pass   4: (0.24 seconds) suminf.    1.33333 (53) obj. 1.21345e+06 iterations 363
# Cbc0038I Pass   5: (0.27 seconds) suminf.    3.88514 (28) obj. 1.38786e+06 iterations 392
# Cbc0038I Pass   6: (0.29 seconds) suminf.    3.00000 (36) obj. 1.45192e+06 iterations 240
# Cbc0038I Pass   7: (0.33 seconds) suminf.    6.34142 (26) obj. 1.52287e+06 iterations 598
# Cbc0038I Pass   8: (0.35 seconds) suminf.    4.31571 (32) obj. 1.48992e+06 iterations 206
# Cbc0038I Pass   9: (0.36 seconds) suminf.    4.31571 (32) obj. 1.48992e+06 iterations 9
# Cbc0038I Pass  10: (0.39 seconds) suminf.    2.94048 (30) obj. 1.54884e+06 iterations 484
# Cbc0038I Pass  11: (0.44 seconds) suminf.    1.33333 (32) obj. 1.59055e+06 iterations 430
# Cbc0038I Pass  12: (0.49 seconds) suminf.    4.50000 (21) obj. 1.47567e+06 iterations 515
# Cbc0038I Pass  13: (0.50 seconds) suminf.    3.00000 (42) obj. 1.55595e+06 iterations 203
# Cbc0038I Pass  14: (0.55 seconds) suminf.    4.22531 (42) obj. 1.59306e+06 iterations 655
# Cbc0038I Pass  15: (0.57 seconds) suminf.    3.00000 (38) obj. 1.59337e+06 iterations 284
# Cbc0038I Pass  16: (0.58 seconds) suminf.    3.00000 (34) obj. 1.60747e+06 iterations 29
# Cbc0038I Pass  17: (0.64 seconds) suminf.    1.87500 (21) obj. 1.61857e+06 iterations 773
# Cbc0038I Pass  18: (0.69 seconds) suminf.    1.33333 (48) obj. 1.61826e+06 iterations 383
# Cbc0038I Pass  19: (0.73 seconds) suminf.    5.15556 (34) obj. 1.65821e+06 iterations 367
# Cbc0038I Pass  20: (0.75 seconds) suminf.    3.12000 (38) obj. 1.6259e+06 iterations 279
# Cbc0038I Pass  21: (0.79 seconds) suminf.    1.66667 (28) obj. 1.62859e+06 iterations 514
# Cbc0038I Pass  22: (0.85 seconds) suminf.    1.33333 (51) obj. 1.62068e+06 iterations 444
# Cbc0038I Pass  23: (0.89 seconds) suminf.    4.81308 (51) obj. 1.57645e+06 iterations 352
# Cbc0038I Pass  24: (0.91 seconds) suminf.    3.15000 (40) obj. 1.58036e+06 iterations 241
# Cbc0038I Pass  25: (0.93 seconds) suminf.    3.00000 (43) obj. 1.60117e+06 iterations 182
# Cbc0038I Pass  26: (0.99 seconds) suminf.    5.00758 (28) obj. 1.61238e+06 iterations 773
# Cbc0038I Pass  27: (1.07 seconds) suminf.    9.55556 (73) obj. 1.93011e+06 iterations 687
# Cbc0038I Pass  28: (1.11 seconds) suminf.    2.75000 (30) obj. 1.87013e+06 iterations 376
# Cbc0038I Pass  29: (1.16 seconds) suminf.    0.91667 (36) obj. 1.85086e+06 iterations 601
# Cbc0038I Pass  30: (1.21 seconds) suminf.    3.33333 (25) obj. 2.03608e+06 iterations 395
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 4394 integers at bound fixed and 134 continuous
# Cbc0038I Full problem 4664 rows 4992 columns, reduced to
# Cbc0010I After 64900 nodes, 13766 on tree, 1265806.3 best solution, best possible 922334.93 (599.64 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 1265806.3 (best possible 922334.93), took 1788835 iterations and 64959 nodes (600.53 seconds)
# Cbc0032I Strong branching done 58462 times (425663 iterations), fathomed 2790 nodes and fixed 2925 variables
# Cbc0035I Maximum depth 434, 2209253 variables fixed on reduced cost
# Cuts at root node changed objective from 918692 to 918692
# Probing was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.499 seconds)
# Gomory was tried 10 times and created 135 cuts of which 0 were active after adding rounds of cuts (0.089 seconds)
# Knapsack was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.062 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 10 times and created 108 cuts of which 0 were active after adding rounds of cuts (0.070 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.048 seconds)
# TwoMirCuts was tried 10 times and created 168 cuts of which 0 were active after adding rounds of cuts (0.071 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                1265806.29093977
# Lower bound:                    922334.926
# Gap:                            0.37
# Enumerated nodes:               64959
# Total iterations:               1788835
# Time (CPU seconds):             600.56
# Time (Wallclock seconds):       607.45
#
# Total time (CPU seconds):       600.66   (Wallclock seconds):       607.54
# WARNING:pyomo.core:Loading a SolverResults object with an 'aborted' status, but containing a solution
# ⏱ Tiempo total: 608.12 segundos
# 📉 Mejor valor encontrado: 1,265,806.29
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5e2082277a518e59df43f23fd9d2a41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&#x27;position: fixed; bottom: 20px; left: 20px; z-index:9999; background-color:white;
#                 padding: 10px; border:2px solid grey; border-radius:6px&#x27;&gt;
#       &lt;h4 style=&#x27;margin-top: 0&#x27;&gt;Vehículos&lt;/h4&gt;
#     &lt;i style=&#x27;background:red;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V1&lt;br&gt;&lt;i style=&#x27;background:blue;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V2&lt;br&gt;&lt;i style=&#x27;background:green;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V3&lt;br&gt;&lt;i style=&#x27;background:purple;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V4&lt;br&gt;&lt;i style=&#x27;background:orange;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V5&lt;br&gt;&lt;i style=&#x27;background:darkred;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V6&lt;br&gt;&lt;i style=&#x27;background:lightblue;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V7&lt;br&gt;&lt;i style=&#x27;background:darkgreen;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V8&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5e2082277a518e59df43f23fd9d2a41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5e2082277a518e59df43f23fd9d2a41 = L.map(
#                 &quot;map_b5e2082277a518e59df43f23fd9d2a41&quot;,
#                 {
#                     center: [4.743359, -74.153536],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_181d0d65f147980758f05c9313f4bc9b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_181d0d65f147980758f05c9313f4bc9b.addTo(map_b5e2082277a518e59df43f23fd9d2a41);
#
#
#             var marker_0289a176409a825d6064c8971a745065 = L.marker(
#                 [4.743359, -74.153536],
#                 {
# }
#             ).addTo(map_b5e2082277a518e59df43f23fd9d2a41);
#
#
#             var icon_654ef957777eedd9808ea72e7f3fe680 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_038f9b1ba5f72ea33eea195057847603 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea87917010855dc60fae3c83c42e598b = $(`&lt;div id=&quot;html_ea87917010855dc60fae3c83c42e598b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CD: CD1&lt;/div&gt;`)[0];
#                 popup_038f9b1ba5f72ea33eea195057847603.setContent(html_ea87917010855dc60fae3c83c42e598b);
#
#
#
#         marker_0289a176409a825d6064c8971a745065.bindPopup(popup_038f9b1ba5f72ea33eea195057847603)
#         ;
#
#
#
#
#                 marker_0289a176409a825d6064c8971a745065.setIcon(icon_654ef957777eedd9808ea72e7f3fe680);
#
#
#             var marker_ad54c7dca254079e8cff3bee4002279b = L.marker(
#                 [4.59795431125545, -74.09893796560621],
#                 {
# }
#             ).addTo(map_b5e2082277a518e59df43f23fd9d2a41);
#
#
#             var icon_e58350c4566a8c236983e7882e6202b6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;gray&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;user&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2b23ca31ead82bf13afb45901debbbd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17f302b55b3e1bad373aa66728328e5f = $(`&lt;div id=&quot;html_17f302b55b3e1bad373aa66728328e5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cliente: C1 Demanda: 13.0&lt;/div&gt;`)[0];
#                 popup_2b23ca31ead82bf13afb45901debbbd7.setContent(html_17f302b55b3e1bad373aa66728328e5f);
#
#
#
#         marker_ad54c7dca254079e8cff3bee4002279b.bindPopup(popup_2b23ca31ead82bf13afb45901debbbd7)
#         ;
#
#
#
#
#                 marker_ad54c7dca254079e8cff3bee4002279b.setIcon(icon_e58350c4566a8c236983e7882e6202b6);
#
#
#             var marker_4147ea59616ad1d88f502068a2faa850 = L.marker(
#                 [4.687820646838871, -74.07557103763986],

# %%
# Puedes cambiar estos datos fácilmente
centros = leer_datos_centro_caso1('depotsC2.csv')
clientes = leer_datos_clientes('clientsC2.csv')
vehiculos = leer_datos_vehiculos('vehiclesC2.csv')


print(centros)
print(clientes)
print(vehiculos)

model = modelo(centros,clientes,vehiculos)
mapa = mostrar_mapa_solucion(model, centros, clientes, vehiculos)
mapa.save("mapa_rutas.html")
mapa
# Out:
# {'CD1': {'lat': 4.75021190869025, 'lon': -74.08124218159384, 'capacidad': 8.0}, 'CD2': {'lat': 4.5363832206427785, 'lon': -74.10993358606953, 'capacidad': 10.0}, 'CD3': {'lat': 4.792925960208614, 'lon': -74.03854814565923, 'capacidad': 0.0}, 'CD4': {'lat': 4.72167778077445, 'lon': -74.06706883098641, 'capacidad': 4.0}, 'CD5': {'lat': 4.607707046760958, 'lon': -74.13826337931849, 'capacidad': 28.0}, 'CD6': {'lat': 4.650463053612691, 'lon': -74.12400186370824, 'capacidad': 3.0}, 'CD7': {'lat': 4.621911772492814, 'lon': -74.09561875464892, 'capacidad': 0.0}, 'CD8': {'lat': 4.678960680833056, 'lon': -74.10975623736951, 'capacidad': 10.0}, 'CD9': {'lat': 4.735973062153282, 'lon': -74.09547235719887, 'capacidad': 43.0}, 'CD10': {'lat': 4.550640992537941, 'lon': -74.10991610076434, 'capacidad': 1.0}, 'CD11': {'lat': 4.664702960902753, 'lon': -74.10977422186991, 'capacidad': 16.0}, 'CD12': {'lat': 4.5791740634103135, 'lon': -74.12408925943333, 'capacidad': 18.0}}
# {'C1': {'lat': 4.632552840424734, 'lon': -74.19699184741948, 'demanda': 12.0}, 'C2': {'lat': 4.601328214582278, 'lon': -74.15503659129905, 'demanda': 15.0}, 'C3': {'lat': 4.732421040989568, 'lon': -74.10178731827096, 'demanda': 15.0}, 'C4': {'lat': 4.638612189685843, 'lon': -74.19486224157397, 'demanda': 6.0}, 'C5': {'lat': 4.727691608175209, 'lon': -74.11027242131048, 'demanda': 5.0}, 'C6': {'lat': 4.665002925306577, 'lon': -74.15228946899238, 'demanda': 11.0}, 'C7': {'lat': 4.6771016997028205, 'lon': -74.03241075805882, 'demanda': 12.0}, 'C8': {'lat': 4.707007012114083, 'lon': -74.0624758742746, 'demanda': 10.0}, 'C9': {'lat': 4.636074548012315, 'lon': -74.09804168568287, 'demanda': 15.0}}
# {'V1': {'capacidad': 131.9211396722696, 'rango': 145.85207096486445}, 'V2': {'capacidad': 108.4356199315333, 'rango': 1304.605971281605}, 'V3': {'capacidad': 91.50425520531195, 'rango': 953.1726086101639}, 'V4': {'capacidad': 32.896064077536955, 'rango': 17.302304187458727}, 'V5': {'capacidad': 22.65262807032524, 'rango': 16.627680130757895}, 'V6': {'capacidad': 22.682911535937688, 'rango': 13.602810739289229}}
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - /usr/bin/cbc -seconds 600 -printingOptions all -import /tmp/tmpzmhy4x9i.pyomo.lp -stat=1 -solve -solu /tmp/tmpzmhy4x9i.pyomo.soln (default strategy 1)
# seconds was changed from 1e+100 to 600
# Option for printingOptions changed from normal to all
# Presolve 651 (-6) rows, 2640 (-6) columns and 11280 (48) elements
# Statistics for presolved model
# Original problem has 2592 integers (2592 of which binary)
# Presolved problem has 2586 integers (2586 of which binary)
# ==== 120 zero objective 211 different
# ==== absolute objective values 211 different
# ==== for integers 66 zero objective 211 different
# ==== for integers absolute objective values 211 different
# ===== end objective counts
#
#
# Problem has 651 rows, 2640 columns (2520 with objective) and 11280 elements
# Column breakdown:
# 0 of type 0.0->inf, 0 of type 0.0->up, 0 of type lo->inf,
# 54 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 2586 of type 0.0->1.0
# Row breakdown:
# 186 of type E 0.0, 21 of type E 1.0, 0 of type E -1.0,
# 0 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 0 of type L 0.0, 0 of type L 1.0,
# 444 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is 194271 - 0.01 seconds
# Cgl0003I 684 fixed, 0 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 617 rows, 1680 columns (1626 integer (1626 of which binary)) and 8096 elements
# Cbc0038I Initial state - 35 integers unsatisfied sum - 1.93041
# Cbc0038I Pass   1: suminf.    0.44444 (4) obj. 204817 iterations 243
# Cbc0038I Pass   2: suminf.    1.85234 (6) obj. 204817 iterations 60
# Cbc0038I Pass   3: suminf.   17.32458 (66) obj. 796666 iterations 232
# Cbc0038I Pass   4: suminf.    0.00000 (0) obj. 632094 iterations 281
# Cbc0038I Solution found of 632094
# Cbc0038I Relaxing continuous gives 632094
# Cbc0038I Before mini branch and bound, 1522 integers at bound fixed and 48 continuous
# Cbc0038I Full problem 617 rows 1680 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from 632094 to 550057 (0.15 seconds)
# Cbc0038I Round again with cutoff of 515533
# Cbc0038I Pass   5: suminf.    0.44444 (4) obj. 204817 iterations 0
# Cbc0038I Pass   6: suminf.    1.85234 (6) obj. 204817 iterations 169
# Cbc0038I Pass   7: suminf.   12.26865 (52) obj. 478495 iterations 236
# Cbc0038I Pass   8: suminf.    3.72152 (16) obj. 312633 iterations 225
# Cbc0038I Pass   9: suminf.    1.85234 (6) obj. 204817 iterations 120
# Cbc0038I Pass  10: suminf.   13.70567 (64) obj. 515533 iterations 219
# Cbc0038I Pass  11: suminf.    0.88889 (4) obj. 413130 iterations 249
# Cbc0038I Pass  12: suminf.    0.44444 (4) obj. 391433 iterations 47
# Cbc0038I Pass  13: suminf.    1.70731 (4) obj. 391433 iterations 80
# Cbc0038I Pass  14: suminf.    1.63275 (4) obj. 391433 iterations 76
# Cbc0038I Pass  15: suminf.   10.40522 (60) obj. 515533 iterations 209
# Cbc0038I Pass  16: suminf.    6.15909 (22) obj. 515533 iterations 204
# Cbc0038I Pass  17: suminf.    2.28601 (15) obj. 515533 iterations 7
# Cbc0038I Pass  18: suminf.    1.99519 (9) obj. 515533 iterations 105
# Cbc0038I Pass  19: suminf.    2.88821 (8) obj. 405119 iterations 129
# Cbc0038I Pass  20: suminf.    2.88821 (8) obj. 405119 iterations 10
# Cbc0038I Pass  21: suminf.    3.00000 (6) obj. 405119 iterations 207
# Cbc0038I Pass  22: suminf.    2.88821 (8) obj. 405119 iterations 132
# Cbc0038I Pass  23: suminf.    3.00000 (6) obj. 405119 iterations 212
# Cbc0038I Pass  24: suminf.    3.00000 (6) obj. 405119 iterations 129
# Cbc0038I Pass  25: suminf.    2.88821 (8) obj. 405119 iterations 171
# Cbc0038I Pass  26: suminf.    3.00000 (6) obj. 405119 iterations 181
# Cbc0038I Pass  27: suminf.    2.23580 (9) obj. 439577 iterations 116
# Cbc0038I Pass  28: suminf.    2.07647 (12) obj. 460803 iterations 27
# Cbc0038I Pass  29: suminf.    3.20871 (11) obj. 515533 iterations 219
# Cbc0038I Pass  30: suminf.    1.63275 (4) obj. 515071 iterations 193
# Cbc0038I Pass  31: suminf.    1.63275 (4) obj. 515071 iterations 7
# Cbc0038I Pass  32: suminf.    1.40380 (4) obj. 515071 iterations 43
# Cbc0038I Pass  33: suminf.    7.33764 (38) obj. 515533 iterations 214
# Cbc0038I Pass  34: suminf.    3.49632 (12) obj. 515533 iterations 161
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1390 integers at bound fixed and 47 continuous
# Cbc0038I Full problem 617 rows 1680 columns, reduced to 61 rows 86 columns
# Cbc0038I Mini branch and bound improved solution from 550057 to 343240 (0.36 seconds)
# Cbc0038I Round again with cutoff of 315555
# Cbc0038I Reduced cost fixing fixed 57 variables on major pass 3
# Cbc0038I Pass  34: suminf.    0.44444 (4) obj. 204817 iterations 0
# Cbc0038I Pass  35: suminf.    1.85234 (6) obj. 204817 iterations 160
# Cbc0038I Pass  36: suminf.    5.85302 (27) obj. 315555 iterations 221
# Cbc0038I Pass  37: suminf.    1.85234 (6) obj. 204817 iterations 175
# Cbc0038I Pass  38: suminf.    4.71497 (16) obj. 315555 iterations 209
# Cbc0038I Pass  39: suminf.    0.00000 (0) obj. 264734 iterations 211
# Cbc0038I Solution found of 264734
# Cbc0038I Relaxing continuous gives 264734
# Cbc0038I Before mini branch and bound, 1560 integers at bound fixed and 50 continuous
# Cbc0038I Full problem 617 rows 1680 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.42 seconds)
# Cbc0038I Round again with cutoff of 246759
# Cbc0038I Reduced cost fixing fixed 826 variables on major pass 4
# Cbc0038I Pass  40: suminf.    0.44444 (4) obj. 204817 iterations 0
# Cbc0038I Pass  41: suminf.    1.85234 (6) obj. 204817 iterations 105
# Cbc0038I Pass  42: suminf.    1.70731 (4) obj. 204817 iterations 131
# Cbc0038I Pass  43: suminf.    1.70731 (4) obj. 204817 iterations 107
# Cbc0038I Pass  44: suminf.    0.44444 (4) obj. 231496 iterations 118
# Cbc0038I Pass  45: suminf.    0.44444 (4) obj. 231496 iterations 98
# Cbc0038I Pass  46: suminf.    1.85234 (6) obj. 231496 iterations 14
# Cbc0038I Pass  47: suminf.    1.28366 (21) obj. 246759 iterations 122
# Cbc0038I Pass  48: suminf.    0.44444 (4) obj. 204817 iterations 114
# Cbc0038I Pass  49: suminf.    0.44444 (4) obj. 204817 iterations 111
# Cbc0038I Pass  50: suminf.    1.85234 (6) obj. 204817 iterations 30
# Cbc0038I Pass  51: suminf.    0.44444 (4) obj. 204817 iterations 23
# Cbc0038I Pass  52: suminf.    6.56172 (22) obj. 246759 iterations 150
# Cbc0038I Pass  53: suminf.    4.74030 (19) obj. 246759 iterations 67
# Cbc0038I Pass  54: suminf.    2.03557 (15) obj. 246759 iterations 177
# Cbc0038I Pass  55: suminf.    1.41053 (4) obj. 245616 iterations 127
# Cbc0038I Pass  56: suminf.    1.70731 (4) obj. 245616 iterations 33
# Cbc0038I Pass  57: suminf.    1.41053 (4) obj. 245616 iterations 76
# Cbc0038I Pass  58: suminf.    1.78543 (9) obj. 246759 iterations 156
# Cbc0038I Pass  59: suminf.    1.48864 (9) obj. 246759 iterations 83
# Cbc0038I Pass  60: suminf.    1.70731 (4) obj. 204817 iterations 96
# Cbc0038I Pass  61: suminf.    1.41053 (4) obj. 204817 iterations 25
# Cbc0038I Pass  62: suminf.    6.41053 (14) obj. 231597 iterations 107
# Cbc0038I Pass  63: suminf.    5.44738 (14) obj. 246759 iterations 124
# Cbc0038I Pass  64: suminf.    3.57153 (9) obj. 246759 iterations 22
# Cbc0038I Pass  65: suminf.    3.57153 (9) obj. 246759 iterations 19
# Cbc0038I Pass  66: suminf.    1.70731 (4) obj. 231496 iterations 91
# Cbc0038I Pass  67: suminf.    1.41053 (4) obj. 231496 iterations 48
# Cbc0038I Pass  68: suminf.    3.68306 (38) obj. 246759 iterations 124
# Cbc0038I Pass  69: suminf.    1.41053 (4) obj. 231496 iterations 112
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1514 integers at bound fixed and 49 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.60 seconds)
# Cbc0038I After 0.60 seconds - Feasibility pump exiting with objective of 264734 - took 0.50 seconds
# Cbc0012I Integer solution of 264734.27 found by feasibility pump after 0 iterations and 0 nodes (0.60 seconds)
# Cbc0038I Full problem 617 rows 1680 columns, reduced to 11 rows 12 columns
# Cbc0031I 13 added rows had average density of 18.846154
# Cbc0013I At root node, 13 cuts changed objective from 204817.18 to 204817.18 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 26 column cuts (26 active)  in 0.098 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 37 row cuts average 301.0 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 14 row cuts average 10.2 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 35 row cuts average 48.0 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 264734.27 best solution, best possible 204817.18 (0.84 seconds)
# Cbc0016I Integer solution of 263494.25 found by strong branching after 196 iterations and 8 nodes (1.00 seconds)
# Cbc0038I Full problem 617 rows 1680 columns, reduced to 15 rows 14 columns
# Cbc0038I Full problem 630 rows 1680 columns, reduced to 439 rows 1082 columns
# Cbc0044I Reduced cost fixing - 439 rows, 1082 columns - restarting search
# Cbc0012I Integer solution of 263494.25 found by Previous solution after 0 iterations and 0 nodes (1.32 seconds)
# Cbc0038I Full problem 439 rows 1082 columns, reduced to 4 rows 4 columns
# Cbc0031I 9 added rows had average density of 22.555556
# Cbc0013I At root node, 9 cuts changed objective from 204817.18 to 204817.18 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 4 column cuts (4 active)  in 0.084 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 20 row cuts average 339.4 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 12 row cuts average 236.1 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 16 row cuts average 18.4 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 9 (Stored from first) - 10 row cuts average 24.3 elements, 0 column cuts (0 active)
# Cbc0010I After 0 nodes, 1 on tree, 263494.25 best solution, best possible 204817.18 (1.50 seconds)
# Cbc0001I Search completed - best objective 263494.2545080986, took 462 iterations and 22 nodes (1.76 seconds)
# Cbc0032I Strong branching done 114 times (1035 iterations), fathomed 1 nodes and fixed 3 variables
# Cbc0035I Maximum depth 9, 2273 variables fixed on reduced cost
# Cbc0038I Probing was tried 27 times and created 67 cuts of which 0 were active after adding rounds of cuts (0.090 seconds)
# Cbc0038I Gomory was tried 26 times and created 37 cuts of which 0 were active after adding rounds of cuts (0.015 seconds)
# Cbc0038I Knapsack was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# Cbc0038I Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Cbc0038I MixedIntegerRounding2 was tried 26 times and created 41 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
# Cbc0038I FlowCover was tried 10 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Cbc0038I TwoMirCuts was tried 21 times and created 64 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Cbc0038I ZeroHalf was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Cbc0038I Stored from first was tried 26 times and created 22 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Cbc0001I Search completed - best objective 263494.2545080986, took 1142 iterations and 72 nodes (1.76 seconds)
# Cbc0032I Strong branching done 218 times (1186 iterations), fathomed 3 nodes and fixed 9 variables
# Cbc0035I Maximum depth 15, 1848 variables fixed on reduced cost
# Cuts at root node changed objective from 204817 to 204817
# Probing was tried 39 times and created 130 cuts of which 0 were active after adding rounds of cuts (0.109 seconds)
# Gomory was tried 37 times and created 54 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
# Knapsack was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 37 times and created 53 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# TwoMirCuts was tried 10 times and created 35 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
#
# Result - Optimal solution found
#
# Objective value:                263494.25450810
# Enumerated nodes:               72
# Total iterations:               1142
# Time (CPU seconds):             1.78
# Time (Wallclock seconds):       1.78
#
# Total time (CPU seconds):       1.82   (Wallclock seconds):       1.83
#
#
# ⏱ Tiempo total: 1.98 segundos
# 📉 Mejor valor encontrado: 263,494.25
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fbc83c87cdda85163e497f2f68f907b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&#x27;position: fixed; bottom: 20px; left: 20px; z-index:9999; background-color:white;
#                 padding: 10px; border:2px solid grey; border-radius:6px&#x27;&gt;
#       &lt;h4 style=&#x27;margin-top: 0&#x27;&gt;Vehículos&lt;/h4&gt;
#     &lt;i style=&#x27;background:red;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V1&lt;br&gt;&lt;i style=&#x27;background:blue;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V2&lt;br&gt;&lt;i style=&#x27;background:green;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V3&lt;br&gt;&lt;i style=&#x27;background:purple;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V4&lt;br&gt;&lt;i style=&#x27;background:orange;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V5&lt;br&gt;&lt;i style=&#x27;background:darkred;width:10px;height:10px;display:inline-block;&#x27;&gt;&lt;/i&gt; V6&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fbc83c87cdda85163e497f2f68f907b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fbc83c87cdda85163e497f2f68f907b = L.map(
#                 &quot;map_3fbc83c87cdda85163e497f2f68f907b&quot;,
#                 {
#                     center: [4.75021190869025, -74.08124218159384],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93ef29f5506b696953d16fe2753ed741 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_93ef29f5506b696953d16fe2753ed741.addTo(map_3fbc83c87cdda85163e497f2f68f907b);
#
#
#             var marker_53677c8f4824c70de42f1986fc82ce47 = L.marker(
#                 [4.75021190869025, -74.08124218159384],
#                 {
# }
#             ).addTo(map_3fbc83c87cdda85163e497f2f68f907b);
#
#
#             var icon_4c298c1ca12ed649fd0b389d77b2096b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8a0ae2a248a2b125579b9a520f954e03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b5be7e2fdb7dadc1247037ba4250161 = $(`&lt;div id=&quot;html_3b5be7e2fdb7dadc1247037ba4250161&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CD: CD1&lt;/div&gt;`)[0];
#                 popup_8a0ae2a248a2b125579b9a520f954e03.setContent(html_3b5be7e2fdb7dadc1247037ba4250161);
#
#
#
#         marker_53677c8f4824c70de42f1986fc82ce47.bindPopup(popup_8a0ae2a248a2b125579b9a520f954e03)
#         ;
#
#
#
#
#                 marker_53677c8f4824c70de42f1986fc82ce47.setIcon(icon_4c298c1ca12ed649fd0b389d77b2096b);
#
#
#             var marker_fc57e3a84c042f81844ddb87c1a50899 = L.marker(
#                 [4.5363832206427785, -74.10993358606953],
#                 {
# }
#             ).addTo(map_3fbc83c87cdda85163e497f2f68f907b);
#
#
#             var icon_37ec85223aa564943f378b17147c61b1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1c68a0b860f63f117bd05061b3b510c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db747fdefb8a8e4fcfdd9c08395e488f = $(`&lt;div id=&quot;html_db747fdefb8a8e4fcfdd9c08395e488f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CD: CD2&lt;/div&gt;`)[0];
#                 popup_1c68a0b860f63f117bd05061b3b510c6.setContent(html_db747fdefb8a8e4fcfdd9c08395e488f);
#
#
#
#         marker_fc57e3a84c042f81844ddb87c1a50899.bindPopup(popup_1c68a0b860f63f117bd05061b3b510c6)
#         ;
#
#
#
#
#                 marker_fc57e3a84c042f81844ddb87c1a50899.setIcon(icon_37ec85223aa564943f378b17147c61b1);
#
#
#             var marker_e79e8e69af3289934fc9ca43ff14c272 = L.marker(
#                 [4.792925960208614, -74.03854814565923],
#                 {
# }
#             ).addTo(map_3fbc83c87cdda85163e497f2f68f907b);
#
#
#             var icon_5ccdcc39277754f7c494b3e7f45ca976 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;:

# %%
import pyomo.environ as pyo
import time
from math import sqrt

def calcular_distancias(nodos, coordenadas):
    """Calcula matriz de distancias (km) entre todos los nodos."""
    distancias = {}
    for i in nodos:
        for j in nodos:
            if i != j:
                dx = coordenadas[i]['lat'] - coordenadas[j]['lat']
                dy = coordenadas[i]['lon'] - coordenadas[j]['lon']
                distancias[(i, j)] = sqrt(dx**2 + dy**2) * 111
    return distancias

def verificar_factibilidad(centros, clientes, vehiculos):
    """Verifica si el problema es factible antes de resolver."""
    deposito = next(iter(centros.keys()))

    # Verificar capacidades
    demanda_total = sum(clientes[c]['demanda'] for c in clientes)
    capacidad_total = sum(vehiculos[v]['capacidad'] for v in vehiculos)

    print(f"📊 Verificación de factibilidad:")
    print(f"   Demanda total: {demanda_total}")
    print(f"   Capacidad total: {capacidad_total}")
    print(f"   Ratio: {demanda_total/capacidad_total:.2%}")

    if demanda_total > capacidad_total:
        print("❌ PROBLEMA NO FACTIBLE: Demanda > Capacidad total")
        return False

    # Verificar si algún cliente tiene demanda > capacidad máxima
    max_capacidad = max(vehiculos[v]['capacidad'] for v in vehiculos)
    max_demanda = max(clientes[c]['demanda'] for c in clientes)

    if max_demanda > max_capacidad:
        print(f"❌ PROBLEMA NO FACTIBLE: Cliente con demanda {max_demanda} > capacidad máxima {max_capacidad}")
        return False

    print("✅ Problema parece factible")
    return True

# Función principal que maneja ambos casos
def modelo_super_rapido(centros, clientes, vehiculos):
    """Modelo ultra-simplificado para obtener solución en < 1 minuto."""
    tiempo_inicio = time.time()

    deposito = next(iter(centros.keys()))
    print(f"🔍 MODO SÚPER RÁPIDO: {len(clientes)} clientes, {len(vehiculos)} vehículos")

    # Modelo simplificado con menos variables
    model = pyo.ConcreteModel()
    model.C = pyo.Set(initialize=list(clientes.keys()))
    model.V = pyo.Set(initialize=list(vehiculos.keys()))

    # Variables principales
    model.x = pyo.Var(model.C, model.V, domain=pyo.Binary)  # Cliente i asignado a vehículo v
    model.y = pyo.Var(model.V, domain=pyo.Binary)  # Vehículo v usado

    # Parámetros
    model.Q = pyo.Param(model.V, initialize={v: vehiculos[v]['capacidad'] for v in vehiculos})
    model.q = pyo.Param(model.C, initialize={c: clientes[c]['demanda'] for c in clientes})

    # Calcular distancias depot-cliente
    dist_depot = {}
    for c in clientes:
        dx = centros[deposito]['lat'] - clientes[c]['lat']
        dy = centros[deposito]['lon'] - clientes[c]['lon']
        dist_depot[c] = sqrt(dx**2 + dy**2) * 111

    costo_por_km = 5000 + 0.025 * 15000 + 700

    # Función objetivo simplificada (solo ida y vuelta al depot)
    def objetivo_simple(m):
        return sum(2 * costo_por_km * dist_depot[c] * m.x[c, v]
                  for c in m.C for v in m.V)

    model.obj = pyo.Objective(expr=objetivo_simple(model), sense=pyo.minimize)

    # Restricciones básicas
    model.asignar_cliente = pyo.Constraint(
        model.C,
        rule=lambda m, c: sum(m.x[c, v] for v in m.V) == 1
    )

    model.capacidad = pyo.Constraint(
        model.V,
        rule=lambda m, v: sum(m.q[c] * m.x[c, v] for c in m.C) <= m.Q[v]
    )

    model.activar_vehiculo = pyo.Constraint(
        model.V,
        rule=lambda m, v: sum(m.x[c, v] for c in m.C) <= len(m.C) * m.y[v]
    )

    # Solver muy agresivo
    solver = pyo.SolverFactory('highs')
    solver.options = {
        'time_limit': 60,  # Solo 1 minuto
        'mip_rel_gap': 0.2,  # 20% gap está bien para velocidad
        'presolve': 'aggressive',
        'parallel': 'on',
        'mip_heuristic_effort': 0.8,  # Máximas heurísticas
        'output_flag': 0  # Sin output para ir más rápido
    }

    print("⚡ Resolviendo modelo súper rápido...")

    try:
        results = solver.solve(model, tee=False, load_solutions=False)

        if results.solver.termination_condition in [pyo.TerminationCondition.optimal,
                                                   pyo.TerminationCondition.feasible]:
            model.solutions.load_from(results)
            tiempo_total = time.time() - tiempo_inicio
            print(f"✅ Solución encontrada en: {tiempo_total:.2f} segundos")
            print(f"💰 Costo aproximado: ${pyo.value(model.obj):,.2f}")
            return model

    except Exception as e:
        print(f"❌ Error: {e}")

# %%
import folium
import random
from folium import plugins
import pyomo.environ as pyo

def mostrar_mapa_solucion_simple(model, centros, clientes, vehiculos):
    """
    Función de visualización compatible con el modelo simplificado.
    Solo muestra asignaciones cliente-vehículo y rutas al depósito.
    """
    # Crear mapa centrado en el primer centro (depósito)
    deposito = next(iter(centros.keys()))
    centro_inicio = centros[deposito]
    mapa = folium.Map(location=[centro_inicio['lat'], centro_inicio['lon']], zoom_start=13)

    # Colores únicos para cada vehículo
    colores = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightblue', 'darkgreen', 'pink', 'gray']
    color_vehiculo = {v: colores[i % len(colores)] for i, v in enumerate(model.V)}

    # Agregar depósito
    folium.Marker(
        [centro_inicio['lat'], centro_inicio['lon']],
        popup=f"Depósito: {deposito}",
        icon=folium.Icon(color='black', icon='home', prefix='fa')
    ).add_to(mapa)

    # Procesar asignaciones y crear rutas
    rutas_por_vehiculo = {}

    for v in model.V:
        rutas_por_vehiculo[v] = []
        carga_total = 0

        # Encontrar clientes asignados a este vehículo
        for c in model.C:
            if pyo.value(model.x[c, v]) == 1:
                rutas_por_vehiculo[v].append(c)
                carga_total += clientes[c]['demanda']

        # Solo procesar vehículos que tienen clientes asignados
        if rutas_por_vehiculo[v]:
            print(f"🚛 Vehículo {v}: {len(rutas_por_vehiculo[v])} clientes, carga: {carga_total}/{vehiculos[v]['capacidad']}")

            # Agregar marcadores para clientes de este vehículo
            for c in rutas_por_vehiculo[v]:
                coord = clientes[c]
                folium.Marker(
                    [coord['lat'], coord['lon']],
                    popup=f"Cliente: {c}<br>Demanda: {clientes[c]['demanda']}<br>Vehículo: {v}",
                    icon=folium.Icon(color=color_vehiculo[v], icon='user', prefix='fa')
                ).add_to(mapa)

                # Dibujar línea del depósito al cliente
                folium.PolyLine(
                    locations=[
                        (centro_inicio['lat'], centro_inicio['lon']),
                        (coord['lat'], coord['lon'])
                    ],
                    color=color_vehiculo[v],
                    weight=3,
                    opacity=0.7,
                    tooltip=f"Vehículo {v} → Cliente {c}"
                ).add_to(mapa)

    # Crear leyenda
    legend_html = """
    <div style='position: fixed; bottom: 20px; left: 20px; z-index:9999; background-color:white;
                padding: 15px; border:2px solid grey; border-radius:8px; box-shadow: 2px 2px 5px rgba(0,0,0,0.3);'>
      <h4 style='margin-top: 0; margin-bottom: 10px; color: #333;'>🚛 Vehículos Activos</h4>
    """

    vehiculos_activos = 0
    for v in model.V:
        if rutas_por_vehiculo[v]:  # Solo mostrar vehículos con clientes
            vehiculos_activos += 1
            num_clientes = len(rutas_por_vehiculo[v])
            carga = sum(clientes[c]['demanda'] for c in rutas_por_vehiculo[v])
            capacidad = vehiculos[v]['capacidad']

            legend_html += f"""
            <div style='margin-bottom: 5px;'>
                <i style='background:{color_vehiculo[v]};width:12px;height:12px;display:inline-block;border-radius:2px;'></i>
                <strong>{v}</strong>: {num_clientes} clientes ({carga}/{capacidad})
            </div>
            """

    legend_html += f"<hr><small><strong>Total:</strong> {vehiculos_activos} vehículos utilizados</small></div>"
    mapa.get_root().html.add_child(folium.Element(legend_html))

    # Agregar información del problema en la esquina superior derecha
    info_html = f"""
    <div style='position: fixed; top: 20px; right: 20px; z-index:9999; background-color:white;
                padding: 10px; border:2px solid grey; border-radius:6px; box-shadow: 2px 2px 5px rgba(0,0,0,0.3);'>
      <h5 style='margin-top: 0; color: #333;'>📊 Resumen</h5>
      <small>
        <strong>Clientes:</strong> {len(model.C)}<br>
        <strong>Vehículos disponibles:</strong> {len(model.V)}<br>
        <strong>Vehículos utilizados:</strong> {vehiculos_activos}<br>
        <strong>Costo total:</strong> ${pyo.value(model.obj):,.0f}
      </small>
    </div>
    """
    mapa.get_root().html.add_child(folium.Element(info_html))

    return mapa

def mostrar_estadisticas_solucion(model, centros, clientes, vehiculos):
    """Muestra estadísticas detalladas de la solución."""
    print("\n" + "="*50)
    print("📈 ESTADÍSTICAS DE LA SOLUCIÓN")
    print("="*50)

    vehiculos_usados = 0
    carga_total_usada = 0
    capacidad_total_disponible = sum(vehiculos[v]['capacidad'] for v in vehiculos)

    for v in model.V:
        clientes_asignados = []
        carga_vehiculo = 0

        for c in model.C:
            if pyo.value(model.x[c, v]) == 1:
                clientes_asignados.append(c)
                carga_vehiculo += clientes[c]['demanda']

        if clientes_asignados:
            vehiculos_usados += 1
            carga_total_usada += carga_vehiculo
            utilizacion = (carga_vehiculo / vehiculos[v]['capacidad']) * 100

            print(f"\n🚛 {v}:")
            print(f"   Clientes: {', '.join(clientes_asignados)}")
            print(f"   Carga: {carga_vehiculo}/{vehiculos[v]['capacidad']} ({utilizacion:.1f}%)")

    eficiencia_flota = (carga_total_usada / capacidad_total_disponible) * 100

    print(f"\n📊 RESUMEN GENERAL:")
    print(f"   Vehículos utilizados: {vehiculos_usados}/{len(vehiculos)}")
    print(f"   Eficiencia de la flota: {eficiencia_flota:.1f}%")
    print(f"   Costo total: ${pyo.value(model.obj):,.2f}")
    print("="*50)

# %%
centros = leer_datos_centro_caso1('depotsC3.csv')
clientes = leer_datos_clientes('clientsC3.csv')
vehiculos = leer_datos_vehiculos('vehiclesC3.csv')


print(centros)
print(clientes)
print(vehiculos)


# Modelo simplificado (rápido pero mejor que heurística)
model = modelo_super_rapido(centros, clientes, vehiculos)

mapa = mostrar_mapa_solucion_simple(model, centros, clientes, vehiculos)
mapa.save("mapa_rutas.html")
mapa
# Out:
# {'CD1': {'lat': 4.75021190869025, 'lon': -74.08124218159384, 'capacidad': 11.0}, 'CD2': {'lat': 4.5363832206427785, 'lon': -74.10993358606953, 'capacidad': 90.0}, 'CD3': {'lat': 4.792925960208614, 'lon': -74.03854814565923, 'capacidad': 130.0}, 'CD4': {'lat': 4.72167778077445, 'lon': -74.06706883098641, 'capacidad': 145.0}, 'CD5': {'lat': 4.607707046760958, 'lon': -74.13826337931849, 'capacidad': 260.0}, 'CD6': {'lat': 4.650463053612691, 'lon': -74.12400186370824, 'capacidad': 180.0}, 'CD7': {'lat': 4.621911772492814, 'lon': -74.09561875464892, 'capacidad': 720.0}, 'CD8': {'lat': 4.678960680833056, 'lon': -74.10975623736951, 'capacidad': 55.0}, 'CD9': {'lat': 4.735973062153282, 'lon': -74.09547235719887, 'capacidad': 70.0}, 'CD10': {'lat': 4.550640992537941, 'lon': -74.10991610076434, 'capacidad': 75.0}, 'CD11': {'lat': 4.664702960902753, 'lon': -74.10977422186991, 'capacidad': 90.0}, 'CD12': {'lat': 4.5791740634103135, 'lon': -74.12408925943333, 'capacidad': 270.0}}
# {'C1': {'lat': 4.679769454542633, 'lon': -74.15080587752655, 'demanda': 12.0}, 'C2': {'lat': 4.733830991590818, 'lon': -74.01799606682779, 'demanda': 12.0}, 'C3': {'lat': 4.620928444870193, 'lon': -74.14365528529937, 'demanda': 12.0}, 'C4': {'lat': 4.7330740665555, 'lon': -74.03458280137461, 'demanda': 12.0}, 'C5': {'lat': 4.820900231096688, 'lon': -74.05588712830665, 'demanda': 12.0}, 'C6': {'lat': 4.779275206620083, 'lon': -74.04633863054056, 'demanda': 12.0}, 'C7': {'lat': 4.723527744298546, 'lon': -74.06470768583738, 'demanda': 12.0}, 'C8': {'lat': 4.551786739961474, 'lon': -74.16228381122208, 'demanda': 12.0}, 'C9': {'lat': 4.7263261853539165, 'lon': -74.09545310710507, 'demanda': 12.0}, 'C10': {'lat': 4.662353891105346, 'lon': -74.06437527371203, 'demanda': 12.0}, 'C11': {'lat': 4.682508652030651, 'lon': -74.14583743858148, 'demanda': 12.0}, 'C12': {'lat': 4.6696470
0}, 'C46': {'lat': 4.586764170616499, 'lon': -74.17871803779973, 'demanda': 12.0}, 'C47': {'lat': 4.735597416649075, 'lon': -74.02905876431227, 'demanda': 12.0}, 'C48': {'lat': 4.6132765247775405, 'lon': -74.13584428090304, 'demanda': 12.0}, 'C49': {'lat': 4.742093515278723, 'lon': -74.10961455253677, 'demanda': 12.0}, 'C50': {'lat': 4.652642561667873, 'lon': -74.08582958932743, 'demanda': 12.0}, 'C51': {'lat': 4.600888205988551, 'lon': -74.157600531395 ...
# {'V1': {'capacidad': 132.0, 'rango': 146.0}, 'V2': {'capacidad': 136.0, 'rango': 196.0}, 'V3': {'capacidad': 115.0, 'rango': 143.0}, 'V4': {'capacidad': 158.0, 'rango': 174.0}, 'V5': {'capacidad': 109.0, 'rango': 167.0}, 'V6': {'capacidad': 109.0, 'rango': 137.0}, 'V7': {'capacidad': 126.0, 'rango': 93.0}, 'V8': {'capacidad': 79.0, 'rango': 134.0}, 'V9': {'capacidad': 96.0, 'rango': 160.0}, 'V10': {'capacidad': 99.0, 'rango': 108.0}, 'V11': {'capacidad': 125.0, 'rango': 955.0}, 'V12': {'capacidad': 98.0, 'rango': 716.0}, 'V13': {'capacidad': 86.0, 'rango': 1023.0}, 'V14': {'capacidad': 74.0, 'rango': 1076.0}, 'V15': {'capacidad': 85.0, 'rango': 942.0}, 'V16': {'capacidad': 22.0, 'rango': 21.0}, 'V17': {'capacidad': 25.0, 'rango': 12.0}, 'V18': {'capacidad': 30.0, 'rango': 12.0}, 'V19': {'capacidad': 27.0, 'rango': 10.0}, 'V20': {'capacidad': 19.0, 'rango': 16.0}, 'V21': {'capacidad': 29.0, 'rango': 16.0}, 'V22': {'capacidad': 25.0, 'rango': 15.0}, 'V23': {'capacidad': 18.0, 'rango': 13.0}, 'V24': {'capacidad': 23.0, 'rango': 19.0}, 'V25': {'capacidad': 27.0, 'rango': 10.0}, 'V26': {'capacidad': 27.0, 'rango': 14.0}, 'V27': {'capacidad': 22.0, 'rango': 17.0}, 'V28': {'capacidad': 31.0, 'rango': 18.0}, 'V29': {'capacidad': 21.0, 'rango': 15.0}, 'V30': {'capacidad': 27.0, 'rango': 18.0}}
# 🔍 MODO SÚPER RÁPIDO: 90 clientes, 30 vehículos
# ⚡ Resolviendo modelo súper rápido...
# ✅ Solución encontrada en: 0.15 segundos
# 💰 Costo aproximado: $14,453,165.12
# 🚛 Vehículo V1: 5 clientes, carga: 60.0/132.0
# 🚛 Vehículo V2: 6 clientes, carga: 72.0/136.0
# 🚛 Vehículo V3: 3 clientes, carga: 32.0/115.0
# 🚛 Vehículo V4: 4 clientes, carga: 48.0/158.0
# 🚛 Vehículo V5: 1 clientes, carga: 12.0/109.0
# 🚛 Vehículo V6: 3 clientes, carga: 36.0/109.0
# 🚛 Vehículo V7: 6 clientes, carga: 69.0/126.0
# 🚛 Vehículo V8: 3 clientes, carga: 36.0/79.0
# 🚛 Vehículo V9: 6 clientes, carga: 72.0/96.0
# 🚛 Vehículo V10: 7 clientes, carga: 84.0/99.0
# 🚛 Vehículo V11: 4 clientes, carga: 48.0/125.0
# 🚛 Vehículo V12: 2 clientes, carga: 24.0/98.0
# 🚛 Vehículo V13: 4 clientes, carga: 48.0/86.0
# 🚛 Vehículo V14: 6 clientes, carga: 72.0/74.0
# 🚛 Vehículo V15: 5 clientes, carga: 60.0/85.0
# 🚛 Vehículo V16: 2 clientes, carga: 17.0/22.0
# 🚛 Vehículo V17: 2 clientes, carga: 24.0/25.0
# 🚛 Vehículo V18: 2 clientes, carga: 21.0/30.0
# 🚛 Vehículo V19: 2 clientes, carga: 24.0/27.0
# 🚛 Vehículo V20: 1 clientes, carga: 12.0/19.0
# 🚛 Vehículo V21: 2 clientes, carga: 24.0/29.0
# 🚛 Vehículo V22: 2 clientes, carga: 24.0/25.0
# 🚛 Vehículo V23: 1 clientes, carga: 12.0/18.0
# 🚛 Vehículo V24: 1 clientes, carga: 12.0/23.0
# 🚛 Vehículo V25: 2 clientes, carga: 24.0/27.0
# 🚛 Vehículo V26: 2 clientes, carga: 24.0/27.0
# 🚛 Vehículo V27: 1 clientes, carga: 12.0/22.0
# 🚛 Vehículo V28: 2 clientes, carga: 24.0/31.0
# 🚛 Vehículo V29: 1 clientes, carga: 12.0/21.0
# 🚛 Vehículo V30: 2 clientes, carga: 24.0/27.0
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_344e16937f63a490a0f30bc34c3519a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&#x27;position: fixed; bottom: 20px; left: 20px; z-index:9999; background-color:white;
#                 padding: 15px; border:2px solid grey; border-radius:8px; box-shadow: 2px 2px 5px rgba(0,0,0,0.3);&#x27;&gt;
#       &lt;h4 style=&#x27;margin-top: 0; margin-bottom: 10px; color: #333;&#x27;&gt;🚛 Vehículos Activos&lt;/h4&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:red;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V1&lt;/strong&gt;: 5 clientes (60.0/132.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:blue;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V2&lt;/strong&gt;: 6 clientes (72.0/136.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:green;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V3&lt;/strong&gt;: 3 clientes (32.0/115.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:purple;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V4&lt;/strong&gt;: 4 clientes (48.0/158.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:orange;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V5&lt;/strong&gt;: 1 clientes (12.0/109.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:darkred;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V6&lt;/strong&gt;: 3 clientes (36.0/109.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:lightblue;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V7&lt;/strong&gt;: 6 clientes (69.0/126.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:darkgreen;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V8&lt;/strong&gt;: 3 clientes (36.0/79.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:pink;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V9&lt;/strong&gt;: 6 clientes (72.0/96.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:gray;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V10&lt;/strong&gt;: 7 clientes (84.0/99.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:red;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V11&lt;/strong&gt;: 4 clientes (48.0/125.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:blue;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V12&lt;/strong&gt;: 2 clientes (24.0/98.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:green;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V13&lt;/strong&gt;: 4 clientes (48.0/86.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:purple;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V14&lt;/strong&gt;: 6 clientes (72.0/74.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:orange;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt;strong&gt;V15&lt;/strong&gt;: 5 clientes (60.0/85.0)
#             &lt;/div&gt;
#
#             &lt;div style=&#x27;margin-bottom: 5px;&#x27;&gt;
#                 &lt;i style=&#x27;background:darkred;width:12px;height:12px;display:inline-block;border-radius:2px;&#x27;&gt;&lt;/i&gt;
#                 &lt
